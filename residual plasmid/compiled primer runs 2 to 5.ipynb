# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Lion\\Documents\\GitHub\\python\\residual plasmid'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'compiled primer runs 2 to 5.csv',
#  'compiled primer runs 2 to 5.ipynb',
#  'compiled primer runs 2 to 5.xlsx']

# %%
df = pd.read_csv('compiled primer runs 2 to 5.csv')

# %%
df.head(50)
# Out:
#     Run   Amp      Conc      CT  Quantity
# 0     1  Amp1    1ng/ul  12.162    1000.0
# 1     1  Amp1  100pg/ul  15.335     100.0
# 2     1  Amp1   10pg/ul  18.688      10.0
# 3     1  Amp1    1pg/ul  22.037       1.0
# 4     1  Amp1  100fg/ul  25.357       0.1
# 5     1  Amp1       NTC   0.000       0.0
# 6     1  Amp2    1ng/ul  12.368    1000.0
# 7     1  Amp2  100pg/ul  15.536     100.0
# 8     1  Amp2   10pg/ul  18.903      10.0
# 9     1  Amp2    1pg/ul  22.237       1.0
# 10    1  Amp2  100fg/ul  25.537       0.1
# 11    1  Amp2       NTC   0.000       0.0
# 12    1  Amp3    1ng/ul  13.180    1000.0
# 13    1  Amp3  100pg/ul  16.427     100.0
# 14    1  Amp3   10pg/ul  19.794      10.0
# 15    1  Amp3    1pg/ul  23.280       1.0
# 16    1  Amp3  100fg/ul  26.639       0.1
# 17    1  Amp3       NTC   0.000       0.0
# 18    1  Amp4    1ng/ul  11.855    1000.0
# 19    1  Amp4  100pg/ul  15.052     100.0
# 20    1  Amp4   10pg/ul  18.400      10.0
# 21    1  Amp4    1pg/ul  21.730       1.0
# 22    1  Amp4  100fg/ul  25.188       0.1
# 23    1  Amp4       NTC   0.000       0.0
# 24    1  Amp5    1ng/ul  11.866    1000.0
# 25    1  Amp5  100pg/ul  14.969     100.0
# 26    1  Amp5   10pg/ul  18.463      10.0
# 27    1  Amp5    1pg/ul  21.645       1.0
# 28    1  Amp5  100fg/ul  24.845       0.1
# 29    1  Amp5       NTC   0.000       0.0
# 30    1  Amp6    1ng/ul  11.966    1000.0
# 31    1  Amp6  100pg/ul  15.359     100.0
# 32    1  Amp6   10pg/ul  18.806      10.0
# 33    1  Amp6    1pg/ul  22.184       1.0
# 34    1  Amp6  100fg/ul  25.651       0.1
# 35    1  Amp6       NTC  36.833       0.0
# 36    1  Amp7    1ng/ul  14.077    1000.0
# 37    1  Amp7  100pg/ul  17.291     100.0
# 38    1  Amp7   10pg/ul  20.610      10.0
# 39    1  Amp7    1pg/ul  24.009       1.0
# 40    1  Amp7  100fg/ul  27.254       0.1
# 41    1  Amp7       NTC   0.000       0.0
# 42    1  Amp8    1ng/ul  13.611    1000.0
# 43    1  Amp8  100pg/ul  16.852     100.0
# 44    1  Amp8   10pg/ul  20.348      10.0
# 45    1  Amp8    1pg/ul  23.579       1.0
# 46    1  Amp8  100fg/ul  26.940       0.1
# 47    1  Amp8       NTC   0.000       0.0
# 48    1  Amp9    1ng/ul  12.332    1000.0
# 49    1  Amp9  100pg/ul  15.521     100.0

# %%
df['CT'].unique()
# Out:
# array([12.162, 15.335, 18.688, 22.037, 25.357,  0.   , 12.368, 15.536,
#        18.903, 22.237, 25.537, 13.18 , 16.427, 19.794, 23.28 , 26.639,
#        11.855, 15.052, 18.4  , 21.73 , 25.188, 11.866, 14.969, 18.463,
#        21.645, 24.845, 11.966, 15.359, 18.806, 22.184, 25.651, 36.833,
#        14.077, 17.291, 20.61 , 24.009, 27.254, 13.611, 16.852, 20.348,
#        23.579, 26.94 , 12.332, 15.521, 18.965, 22.148, 25.803, 12.25 ,
#        15.387, 18.78 , 22.232, 25.472, 12.34 , 12.267, 15.727, 15.613,
#        19.138, 19.213, 22.276, 22.394, 25.425, 25.589, 37.051, 37.659,
#        12.275, 12.147, 15.239, 15.242, 18.957, 19.136, 21.955, 21.989,
#        25.667, 26.271, 36.362, 35.764, 12.423, 15.458, 15.319, 18.731,
#        18.718, 21.92 , 22.108, 25.739, 25.852, 37.364, 35.515, 12.531,
#        12.558, 15.574, 15.824, 19.482, 19.426, 22.526, 22.545, 26.061,
#        25.94 , 37.568, 12.428, 12.448, 15.853, 15.834, 19.449, 19.468,
#        22.459, 22.534, 26.608, 26.316, 35.579, 35.602, 12.357, 12.286,
#        15.71 , 15.664, 19.689, 19.697, 22.675, 22.738, 25.845, 25.917,
#        35.921, 38.156, 11.972, 11.887, 15.447, 15.417, 19.299, 19.345,
#        22.397, 21.897, 25.572, 24.671, 34.145, 34.65 , 12.051, 12.083,
#        15.144, 15.187, 18.602, 18.644, 21.878, 21.944, 24.737, 24.653,
#        33.282, 34.46 , 12.561, 12.603, 15.625, 15.566, 19.137, 19.202,
#        22.455, 22.402, 25.33 , 26.405, 35.938, 35.94 , 12.454, 12.517,
#        15.621, 15.661, 19.078, 19.19 , 23.063, 22.941, 26.373, 26.325,
#        34.1  , 34.072, 12.342, 12.156, 15.654, 15.643, 18.949, 18.921,
#        22.463, 22.52 , 26.315, 26.338, 11.957, 11.779, 15.264, 15.186,
#        18.604, 18.677, 22.253, 22.289, 26.139, 25.926, 12.046, 11.875,
#        15.362, 15.26 , 18.592, 18.647, 22.093, 22.136, 25.752, 25.685,
#        12.297, 15.785, 15.659, 19.141, 19.013, 22.661, 22.589, 26.414,
#        26.324, 12.388, 11.961, 15.698, 15.605, 19.063, 18.896, 22.586,
#        22.633, 26.479, 38.172])

# %%
df.groupby(by=['Run','Amp']).mean()
# Out:
#                   CT    Quantity
# Run Amp
# 1   Amp1   15.596500  185.183333
#     Amp10  15.686833  185.183333
#     Amp2   15.763500  185.183333
#     Amp3   16.553333  185.183333
#     Amp4   15.370833  185.183333
#     Amp5   15.298000  185.183333
#     Amp6   21.799833  185.183333
#     Amp7   17.206833  185.183333
#     Amp8   16.888333  185.183333
#     Amp9   15.794833  185.183333
# 2   Amp1   22.057667  202.018182
#     Amp10  22.048167  185.183333
#     Amp4   21.750333  202.018182
#     Amp5   21.789917  185.183333
#     Amp9   19.169583  185.183333
# 3   Amp1   22.221250  185.183333
#     Amp10  21.782917  185.183333
#     Amp4   21.391583  185.183333
#     Amp5   21.055417  185.183333
#     Amp9   21.930333  185.183333
# 4   Amp1   15.941750  185.183333
#     Amp10  19.150417  185.183333
#     Amp4   15.672833  185.183333
#     Amp5   15.620667  185.183333
#     Amp9   16.025500  185.183333

# %%
df[df['CT'] != 0]
# Out:
#      Run    Amp      Conc      CT  Quantity
# 0      1   Amp1    1ng/ul  12.162    1000.0
# 1      1   Amp1  100pg/ul  15.335     100.0
# 2      1   Amp1   10pg/ul  18.688      10.0
# 3      1   Amp1    1pg/ul  22.037       1.0
# 4      1   Amp1  100fg/ul  25.357       0.1
# ..   ...    ...       ...     ...       ...
# 234    4  Amp10    1pg/ul  22.586       1.0
# 235    4  Amp10    1pg/ul  22.633       1.0
# 236    4  Amp10  100fg/ul  26.324       0.1
# 237    4  Amp10  100fg/ul  26.479       0.1
# 238    4  Amp10       NTC  38.172       0.0
#
# [221 rows x 5 columns]

# %%
df_withoutzero = df[df['CT'] != 0]

# %%
plt.figure(figsize=(20,20))

sns.catplot(data=df_withoutzero,
            x='Amp',
            y='CT',
           kind='box',
           height=10, # have to use this to change  plot size
           #color = 'grey',
           hue = 'Conc')

sns.stripplot(x='Amp', y='CT', 
              data=df_withoutzero, 
              hue='Run',
              marker='o',
              size=10, #size of marker
              alpha=0.5)

plt.legend(bbox_to_anchor = (1.05,1))

# %%
df_withoutzero
# Out:
#      Run    Amp      Conc      CT  Quantity
# 0      1   Amp1    1ng/ul  12.162    1000.0
# 1      1   Amp1  100pg/ul  15.335     100.0
# 2      1   Amp1   10pg/ul  18.688      10.0
# 3      1   Amp1    1pg/ul  22.037       1.0
# 4      1   Amp1  100fg/ul  25.357       0.1
# ..   ...    ...       ...     ...       ...
# 234    4  Amp10    1pg/ul  22.586       1.0
# 235    4  Amp10    1pg/ul  22.633       1.0
# 236    4  Amp10  100fg/ul  26.324       0.1
# 237    4  Amp10  100fg/ul  26.479       0.1
# 238    4  Amp10       NTC  38.172       0.0
#
# [221 rows x 5 columns]

# %%
df_withoutzero['Quantity']
# Out:
# pandas.core.series.Series

# %%
type(df_withoutzero['Quantity'][1])
# Out:
# numpy.float64

# %%
df['Quantity'] = df['Quantity'].astype(float)

# %%
plt.figure(figsize=(12,8),dpi=-200)
sns.catplot(x="Amp", y="CT",
            #hue="Run",
            col="Conc",
            data=df_withoutzero,
            kind="box",
            height=10, aspect=1,
           col_wrap=2,
           sharey=False)

# %%
df_withoutzero['Quantity'].unique()
# Out:
# array([1.e+03, 1.e+02, 1.e+01, 1.e+00, 1.e-01, 0.e+00,    nan])

# %%
plt.figure(figsize=(12,8),dpi=200)
g = sns.FacetGrid(df_withoutzero,
                 col = 'Conc',
                 col_wrap=2)
g.map(sns.lineplot,'Quantity','CT')

# %%
np.log10(df_withoutzero['Quantity'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\arraylike.py:358: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# 0      3.0
# 1      2.0
# 2      1.0
# 3      0.0
# 4     -1.0
#       ...
# 234    0.0
# 235    0.0
# 236   -1.0
# 237   -1.0
# 238   -inf
# Name: Quantity, Length: 221, dtype: float64

# %%
plt.figure(dpi=200)
sns.relplot(x=np.log10(df_withoutzero['Quantity']), y="CT",
            #hue="Run",
            col="Amp",
            data=df_withoutzero,
            kind="line",
            height=8, aspect=1,
           col_wrap=2)
plt.xlabel('Log10 Concentration in pg/ul')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\arraylike.py:358: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Text(0.5, 6.79999999999923, 'Log10 Concentration in pg/ul')

# %%
df_withoutzero_quant = df_withoutzero = df[df['Quantity'] != 0]

# %%
df_withoutzero_quant['Quantity'] = np.log10(df_withoutzero_quant['Quantity'])
# Out:
# <ipython-input-10-9cb4ab37474f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_withoutzero_quant['Quantity'] = np.log10(df_withoutzero_quant['Quantity'])

# %%
df_withoutzero_quant['Quantity']
# Out:
# 0      3.0
# 1      2.0
# 2      1.0
# 3      0.0
# 4     -1.0
#       ...
# 233    1.0
# 234    0.0
# 235    0.0
# 236   -1.0
# 237   -1.0
# Name: Quantity, Length: 202, dtype: float64

# %%
df_withoutzero_quant
# Out:
#      Run    Amp      Conc      CT  Quantity
# 0      1   Amp1    1ng/ul  12.162       3.0
# 1      1   Amp1  100pg/ul  15.335       2.0
# 2      1   Amp1   10pg/ul  18.688       1.0
# 3      1   Amp1    1pg/ul  22.037       0.0
# 4      1   Amp1  100fg/ul  25.357      -1.0
# ..   ...    ...       ...     ...       ...
# 233    4  Amp10   10pg/ul  18.896       1.0
# 234    4  Amp10    1pg/ul  22.586       0.0
# 235    4  Amp10    1pg/ul  22.633       0.0
# 236    4  Amp10  100fg/ul  26.324      -1.0
# 237    4  Amp10  100fg/ul  26.479      -1.0
#
# [202 rows x 5 columns]

# %%
from scipy import stats

# %%
df.groupby(['Amp','Quantity']).mean()
# Out:
#                      Run         CT
# Amp   Quantity
# Amp1  0.0       2.833333  18.521333
#       0.1       2.714286  25.826571
#       1.0       2.714286  22.443286
#       10.0      2.714286  19.185000
#       100.0     2.714286  15.620857
#       1000.0    2.714286  12.272857
# Amp10 0.0       2.714286  25.360714
#       0.1       2.714286  26.271000
#       1.0       2.714286  22.635429
#       10.0      2.714286  19.132000
#       100.0     2.714286  15.665571
#       1000.0    2.714286  12.349429
# Amp2  0.0       1.000000   0.000000
#       0.1       1.000000  25.537000
#       1.0       1.000000  22.237000
#       10.0      1.000000  18.903000
#       100.0     1.000000  15.536000
#       1000.0    1.000000  12.368000
# Amp3  0.0       1.000000   0.000000
#       0.1       1.000000  26.639000
#       1.0       1.000000  23.280000
#       10.0      1.000000  19.794000
#       100.0     1.000000  16.427000
#       1000.0    1.000000  13.180000
# Amp4  0.0       2.833333  17.526167
#       0.1       2.714286  25.633429
#       1.0       2.714286  22.072857
#       10.0      2.714286  18.916857
#       100.0     2.714286  15.263857
#       1000.0    2.714286  11.981714
# Amp5  0.0       2.714286  20.088714
#       0.1       2.714286  25.323286
#       1.0       2.714286  21.960571
#       10.0      2.714286  18.628143
#       100.0     2.714286  15.242714
#       1000.0    2.714286  12.096571
# Amp6  0.0       1.000000  36.833000
#       0.1       1.000000  25.651000
#       1.0       1.000000  22.184000
#       10.0      1.000000  18.806000
#       100.0     1.000000  15.359000
#       1000.0    1.000000  11.966000
# Amp7  0.0       1.000000   0.000000
#       0.1       1.000000  27.254000
#       1.0       1.000000  24.009000
#       10.0      1.000000  20.610000
#       100.0     1.000000  17.291000
#       1000.0    1.000000  14.077000
# Amp8  0.0       1.000000   0.000000
#       0.1       1.000000  26.940000
#       1.0       1.000000  23.579000
#       10.0      1.000000  20.348000
#       100.0     1.000000  16.852000
#       1000.0    1.000000  13.611000
# Amp9  0.0       2.714286  15.635143
#       0.1       2.714286  26.039571
#       1.0       2.714286  22.475143
#       10.0      2.714286  19.195143
#       100.0     2.714286  15.650571
#       1000.0    2.714286  12.472143

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress(df_withoutzero_quant['Quantity'],df_withoutzero_quant['CT'])

# %%
slope, intercept
# Out:
# (nan, nan)

# %%
g = sns.FacetGrid(df_withoutzero,
                 col = 'Amp',
                 col_wrap=2)
g.map(sns.regplot,'Quantity','CT')

# %%
sns.regplot(data=df_withoutzero_quant,x='Quantity',y='CT',
           stat)
# Out:
# <AxesSubplot:xlabel='Quantity', ylabel='CT'>

# %%
df
# Out:
#      Run    Amp      Conc      CT  Quantity
# 0      1   Amp1    1ng/ul  12.162    1000.0
# 1      1   Amp1  100pg/ul  15.335     100.0
# 2      1   Amp1   10pg/ul  18.688      10.0
# 3      1   Amp1    1pg/ul  22.037       1.0
# 4      1   Amp1  100fg/ul  25.357       0.1
# ..   ...    ...       ...     ...       ...
# 235    4  Amp10    1pg/ul  22.633       1.0
# 236    4  Amp10  100fg/ul  26.324       0.1
# 237    4  Amp10  100fg/ul  26.479       0.1
# 238    4  Amp10       NTC  38.172       0.0
# 239    4  Amp10       NTC   0.000       0.0
#
# [240 rows x 5 columns]

# %%
sns.boxplot(data = df_withoutzero_quant,
               x='Amp',
               y='CT')
# Out:
# <AxesSubplot:xlabel='Amp', ylabel='CT'>

# %%
df_withoutzero_quant_5amp = df_withoutzero_quant[df_withoutzero_quant['Amp'].isin(['Amp1','Amp4','Amp5','Amp9','Amp10'])]

# %%
df_withoutzero_quant_5amp = df_withoutzero_quant_5amp.fillna(0)

# %%
df_withoutzero_quant_5amp.head(50)
# Out:
#     Run    Amp      Conc      CT  Quantity
# 0     1   Amp1    1ng/ul  12.162       3.0
# 1     1   Amp1  100pg/ul  15.335       2.0
# 2     1   Amp1   10pg/ul  18.688       1.0
# 3     1   Amp1    1pg/ul  22.037       0.0
# 4     1   Amp1  100fg/ul  25.357      -1.0
# 18    1   Amp4    1ng/ul  11.855       3.0
# 19    1   Amp4  100pg/ul  15.052       2.0
# 20    1   Amp4   10pg/ul  18.400       1.0
# 21    1   Amp4    1pg/ul  21.730       0.0
# 22    1   Amp4  100fg/ul  25.188      -1.0
# 24    1   Amp5    1ng/ul  11.866       3.0
# 25    1   Amp5  100pg/ul  14.969       2.0
# 26    1   Amp5   10pg/ul  18.463       1.0
# 27    1   Amp5    1pg/ul  21.645       0.0
# 28    1   Amp5  100fg/ul  24.845      -1.0
# 48    1   Amp9    1ng/ul  12.332       3.0
# 49    1   Amp9  100pg/ul  15.521       2.0
# 50    1   Amp9   10pg/ul  18.965       1.0
# 51    1   Amp9    1pg/ul  22.148       0.0
# 52    1   Amp9  100fg/ul  25.803      -1.0
# 54    1  Amp10    1ng/ul  12.250       3.0
# 55    1  Amp10  100pg/ul  15.387       2.0
# 56    1  Amp10   10pg/ul  18.780       1.0
# 57    1  Amp10    1pg/ul  22.232       0.0
# 58    1  Amp10  100fg/ul  25.472      -1.0
# 60    2   Amp1    1ng/ul  12.340       3.0
# 61    2   Amp1    1ng/ul  12.267       3.0
# 62    2   Amp1  100pg/ul  15.727       2.0
# 63    2   Amp1  100pg/ul  15.613       2.0
# 64    2   Amp1   10pg/ul  19.138       1.0
# 65    2   Amp1   10pg/ul  19.213       1.0
# 66    2   Amp1    1pg/ul  22.276       0.0
# 67    2   Amp1    1pg/ul  22.394       0.0
# 68    2   Amp1  100fg/ul  25.425      -1.0
# 69    2   Amp1  100fg/ul  25.589      -1.0
# 71    2   Amp1       NTC  37.659       0.0
# 72    2   Amp4    1ng/ul  12.275       3.0
# 73    2   Amp4    1ng/ul  12.147       3.0
# 74    2   Amp4  100pg/ul  15.239       2.0
# 75    2   Amp4  100pg/ul  15.242       2.0
# 76    2   Amp4   10pg/ul  18.957       1.0
# 77    2   Amp4   10pg/ul  19.136       1.0
# 78    2   Amp4    1pg/ul  21.955       0.0
# 79    2   Amp4    1pg/ul  21.989       0.0
# 80    2   Amp4  100fg/ul  25.667      -1.0
# 81    2   Amp4  100fg/ul  26.271      -1.0
# 83    2   Amp4       NTC  35.764       0.0
# 84    2   Amp5    1ng/ul  12.423       3.0
# 85    2   Amp5    1ng/ul  12.332       3.0
# 86    2   Amp5  100pg/ul  15.458       2.0

# %%
# manual mode of assigning the 'Amp' data to the respective variables
# we will call this step 'manual filtering for Amp'
amp1 = df_withoutzero_quant_5amp[df_withoutzero_quant_5amp['Amp']=='Amp1']
amp4 = df_withoutzero_quant_5amp[df_withoutzero_quant_5amp['Amp']=='Amp4']
amp5 = df_withoutzero_quant_5amp[df_withoutzero_quant_5amp['Amp']=='Amp5']
amp9 = df_withoutzero_quant_5amp[df_withoutzero_quant_5amp['Amp']=='Amp9']
amp10 = df_withoutzero_quant_5amp[df_withoutzero_quant_5amp['Amp']=='Amp10']

# %%
# check to see how many unique 'Amp's we have. should be 5
len(df_withoutzero_quant_5amp['Amp'].unique())
# Out:
# 5

# %%
# loop method to generate a dictionary of the DataFrame for each 'Amp'
# see 'manual filtering for Amp' step
# since we have Amp1,4,5,9, and 10, we cannot just use 'for amp in range()', because
# it will return us the values in chronological order. What we want is in the specific order
# of '1,4,5,9,10'

# so over here, we are creating

dict_amp = {}
for amp in [1,4,5,9,10]:
#range(0,len(df_withoutzero_quant_5amp['Amp'].unique())):
    print(amp)
    dict_amp['Amp'+str(amp)] = df_withoutzero_quant_5amp[df_withoutzero_quant_5amp['Amp']==('Amp'+str(amp))]

dict_amp['Amp1']
# Out:
# 1
# 4
# 5
# 9
# 10
#      Run   Amp      Conc      CT  Quantity
# 0      1  Amp1    1ng/ul  12.162       3.0
# 1      1  Amp1  100pg/ul  15.335       2.0
# 2      1  Amp1   10pg/ul  18.688       1.0
# 3      1  Amp1    1pg/ul  22.037       0.0
# 4      1  Amp1  100fg/ul  25.357      -1.0
# 60     2  Amp1    1ng/ul  12.340       3.0
# 61     2  Amp1    1ng/ul  12.267       3.0
# 62     2  Amp1  100pg/ul  15.727       2.0
# 63     2  Amp1  100pg/ul  15.613       2.0
# 64     2  Amp1   10pg/ul  19.138       1.0
# 65     2  Amp1   10pg/ul  19.213       1.0
# 66     2  Amp1    1pg/ul  22.276       0.0
# 67     2  Amp1    1pg/ul  22.394       0.0
# 68     2  Amp1  100fg/ul  25.425      -1.0
# 69     2  Amp1  100fg/ul  25.589      -1.0
# 71     2  Amp1       NTC  37.659       0.0
# 120    3  Amp1    1ng/ul  12.357       3.0
# 121    3  Amp1    1ng/ul  12.286       3.0
# 122    3  Amp1  100pg/ul  15.710       2.0
# 123    3  Amp1  100pg/ul  15.664       2.0
# 124    3  Amp1   10pg/ul  19.689       1.0
# 125    3  Amp1   10pg/ul  19.697       1.0
# 126    3  Amp1    1pg/ul  22.675       0.0
# 127    3  Amp1    1pg/ul  22.738       0.0
# 128    3  Amp1  100fg/ul  25.845      -1.0
# 129    3  Amp1  100fg/ul  25.917      -1.0
# 180    4  Amp1    1ng/ul  12.342       3.0
# 181    4  Amp1    1ng/ul  12.156       3.0
# 182    4  Amp1  100pg/ul  15.654       2.0
# 183    4  Amp1  100pg/ul  15.643       2.0
# 184    4  Amp1   10pg/ul  18.949       1.0
# 185    4  Amp1   10pg/ul  18.921       1.0
# 186    4  Amp1    1pg/ul  22.463       0.0
# 187    4  Amp1    1pg/ul  22.520       0.0
# 188    4  Amp1  100fg/ul  26.315      -1.0
# 189    4  Amp1  100fg/ul  26.338      -1.0

# %%
dict_amp['Amp10']
# Out:
#      Run    Amp      Conc      CT  Quantity
# 54     1  Amp10    1ng/ul  12.250       3.0
# 55     1  Amp10  100pg/ul  15.387       2.0
# 56     1  Amp10   10pg/ul  18.780       1.0
# 57     1  Amp10    1pg/ul  22.232       0.0
# 58     1  Amp10  100fg/ul  25.472      -1.0
# 108    2  Amp10    1ng/ul  12.428       3.0
# 109    2  Amp10    1ng/ul  12.448       3.0
# 110    2  Amp10  100pg/ul  15.853       2.0
# 111    2  Amp10  100pg/ul  15.834       2.0
# 112    2  Amp10   10pg/ul  19.449       1.0
# 113    2  Amp10   10pg/ul  19.468       1.0
# 114    2  Amp10    1pg/ul  22.459       0.0
# 115    2  Amp10    1pg/ul  22.534       0.0
# 116    2  Amp10  100fg/ul  26.608      -1.0
# 117    2  Amp10  100fg/ul  26.316      -1.0
# 168    3  Amp10    1ng/ul  12.454       3.0
# 169    3  Amp10    1ng/ul  12.517       3.0
# 170    3  Amp10  100pg/ul  15.621       2.0
# 171    3  Amp10  100pg/ul  15.661       2.0
# 172    3  Amp10   10pg/ul  19.078       1.0
# 173    3  Amp10   10pg/ul  19.190       1.0
# 174    3  Amp10    1pg/ul  23.063       0.0
# 175    3  Amp10    1pg/ul  22.941       0.0
# 176    3  Amp10  100fg/ul  26.373      -1.0
# 177    3  Amp10  100fg/ul  26.325      -1.0
# 228    4  Amp10    1ng/ul  12.388       3.0
# 229    4  Amp10    1ng/ul  11.961       3.0
# 230    4  Amp10  100pg/ul  15.698       2.0
# 231    4  Amp10  100pg/ul  15.605       2.0
# 232    4  Amp10   10pg/ul  19.063       1.0
# 233    4  Amp10   10pg/ul  18.896       1.0
# 234    4  Amp10    1pg/ul  22.586       0.0
# 235    4  Amp10    1pg/ul  22.633       0.0
# 236    4  Amp10  100fg/ul  26.324      -1.0
# 237    4  Amp10  100fg/ul  26.479      -1.0

# %%
 slope, intercept, r_value, p_value, std_err = stats.linregress(
    dict_amp['Amp1'].groupby(by=['Run','Conc']).mean().xs(key=1,level='Run')['Quantity'],
    dict_amp['Amp1'].groupby(by=['Run','Conc']).mean().xs(key=1,level='Run')['CT'])

# %%
slope
# Out:
# -3.3092

# %%
stats_list = []
def get_stats(dict_amp):
    slope, intercept, r_value, p_value, std_err = stats.linregress(
    dict_amp.groupby(by=['Run','Conc']).mean().xs(key=1,level='Run')['Quantity'],
    dict_amp.groupby(by=['Run','Conc']).mean().xs(key=1,level='Run')['CT'])
    stats_list.append([slope, intercept, r_value, p_value, std_err])

# %%
get_stats(dict_amp['Amp1'])

# %%
stats_list
# Out:
# [[-3.3092,
#   22.025000000000002,
#   -0.9999509825489866,
#   4.1196161252300284e-07,
#   0.018917716564075492]]

# %%
stats_list = []
index_names = []
for amp in df_withoutzero_quant_5amp['Amp'].unique():
    print(amp)
    get_stats(dict_amp[str(amp)])
    index_names.append(amp)
# Out:
# Amp1
# Amp4
# Amp5
# Amp9
# Amp10

# %%
stats_list
# Out:
# [[-3.3092,
#   22.025000000000002,
#   -0.9999509825489866,
#   4.1196161252300284e-07,
#   0.018917716564075492],
#  [-3.3343999999999996,
#   21.7794,
#   -0.9999118033317193,
#   9.942746827808058e-07,
#   0.02556977382250136],
#  [-3.2634000000000003,
#   21.621,
#   -0.9998584703140501,
#   2.021137927366622e-06,
#   0.03170257613085176],
#  [-3.3569000000000004,
#   22.3107,
#   -0.999737631611078,
#   5.101337155173037e-06,
#   0.04440521741116426],
#  [-3.3289000000000004,
#   22.153100000000002,
#   -0.9998782133052824,
#   1.613339212066037e-06,
#   0.029998166610645714]]

# %%
pd.DataFrame(stats_list,index = index_names,
             columns = ['slope','intercept','r_value', 'p_value', 'std_err'])
# Out:
#         slope  intercept   r_value       p_value   std_err
# Amp1  -3.3092    22.0250 -0.999951  4.119616e-07  0.018918
# Amp4  -3.3344    21.7794 -0.999912  9.942747e-07  0.025570
# Amp5  -3.2634    21.6210 -0.999858  2.021138e-06  0.031703
# Amp9  -3.3569    22.3107 -0.999738  5.101337e-06  0.044405
# Amp10 -3.3289    22.1531 -0.999878  1.613339e-06  0.029998

# %%
amp1.groupby(by=['Run','Conc']).mean().xs(key=1,level='Run')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-bd4ca410e3fa> in <module>
# ----> 1 amp1.groupby(by=['Run','Conc']).mean().xs(key=1,level='Run')
#
# NameError: name 'amp1' is not defined

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress(
    amp1.groupby(by=['Run','Conc']).mean().xs(key=1,level='Run')['Quantity'],
    amp1.groupby(by=['Run','Conc']).mean().xs(key=1,level='Run')['CT'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-e07f47a15855> in <module>
#       1 slope, intercept, r_value, p_value, std_err = stats.linregress(
# ----> 2     amp1.groupby(by=['Run','Conc']).mean().xs(key=1,level='Run')['Quantity'],
#       3     amp1.groupby(by=['Run','Conc']).mean().xs(key=1,level='Run')['CT'])
#
# NameError: name 'amp1' is not defined

# %%
slope, intercept, r_value, p_value, std_err
# Out:
# (-3.3092,
#  22.025000000000002,
#  -0.9999509825489866,
#  4.1196161252300284e-07,
#  0.018917716564075492)

# %%
stats_list = []

def get_stats(amp):
    slope, intercept, r_value, p_value, std_err = stats.linregress(
    amp.groupby(by=['Run','Conc']).mean().xs(key=1,level='Run')['Quantity'],
    amp.groupby(by=['Run','Conc']).mean().xs(key=1,level='Run')['CT'])
    stats_list.append([slope, intercept, r_value, p_value, std_err])
    
get_stats(amp1)
get_stats(amp4)
get_stats(amp5)
get_stats(amp9)
get_stats(amp10)

#for n in df_withoutzero_quant_5amp['Amp'].unique():
#    get_stats(n)

# %%
amp1
# Out:
#      Run   Amp      Conc      CT  Quantity
# 0      1  Amp1    1ng/ul  12.162       3.0
# 1      1  Amp1  100pg/ul  15.335       2.0
# 2      1  Amp1   10pg/ul  18.688       1.0
# 3      1  Amp1    1pg/ul  22.037       0.0
# 4      1  Amp1  100fg/ul  25.357      -1.0
# 60     2  Amp1    1ng/ul  12.340       3.0
# 61     2  Amp1    1ng/ul  12.267       3.0
# 62     2  Amp1  100pg/ul  15.727       2.0
# 63     2  Amp1  100pg/ul  15.613       2.0
# 64     2  Amp1   10pg/ul  19.138       1.0
# 65     2  Amp1   10pg/ul  19.213       1.0
# 66     2  Amp1    1pg/ul  22.276       0.0
# 67     2  Amp1    1pg/ul  22.394       0.0
# 68     2  Amp1  100fg/ul  25.425      -1.0
# 69     2  Amp1  100fg/ul  25.589      -1.0
# 71     2  Amp1       NTC  37.659       0.0
# 120    3  Amp1    1ng/ul  12.357       3.0
# 121    3  Amp1    1ng/ul  12.286       3.0
# 122    3  Amp1  100pg/ul  15.710       2.0
# 123    3  Amp1  100pg/ul  15.664       2.0
# 124    3  Amp1   10pg/ul  19.689       1.0
# 125    3  Amp1   10pg/ul  19.697       1.0
# 126    3  Amp1    1pg/ul  22.675       0.0
# 127    3  Amp1    1pg/ul  22.738       0.0
# 128    3  Amp1  100fg/ul  25.845      -1.0
# 129    3  Amp1  100fg/ul  25.917      -1.0
# 180    4  Amp1    1ng/ul  12.342       3.0
# 181    4  Amp1    1ng/ul  12.156       3.0
# 182    4  Amp1  100pg/ul  15.654       2.0
# 183    4  Amp1  100pg/ul  15.643       2.0
# 184    4  Amp1   10pg/ul  18.949       1.0
# 185    4  Amp1   10pg/ul  18.921       1.0
# 186    4  Amp1    1pg/ul  22.463       0.0
# 187    4  Amp1    1pg/ul  22.520       0.0
# 188    4  Amp1  100fg/ul  26.315      -1.0
# 189    4  Amp1  100fg/ul  26.338      -1.0

# %%
stats_list
# Out:
# [[-3.3092,
#   22.025000000000002,
#   -0.9999509825489866,
#   4.1196161252300284e-07,
#   0.018917716564075492],
#  [-3.3343999999999996,
#   21.7794,
#   -0.9999118033317193,
#   9.942746827808058e-07,
#   0.02556977382250136],
#  [-3.2634000000000003,
#   21.621,
#   -0.9998584703140501,
#   2.021137927366622e-06,
#   0.03170257613085176],
#  [-3.3569000000000004,
#   22.3107,
#   -0.999737631611078,
#   5.101337155173037e-06,
#   0.04440521741116426],
#  [-3.3289000000000004,
#   22.153100000000002,
#   -0.9998782133052824,
#   1.613339212066037e-06,
#   0.029998166610645714]]

# %%
stats_list[0][1]
# Out:
# 22.025000000000002

# %%
pd.DataFrame(stats_list,index = ['Amp1','Amp4','Amp5','Amp9','Amp10'],
             columns = ['slope','intercept','r_value', 'p_value', 'std_err'])
# Out:
#         slope  intercept   r_value       p_value   std_err
# Amp1  -3.3092    22.0250 -0.999951  4.119616e-07  0.018918
# Amp4  -3.3344    21.7794 -0.999912  9.942747e-07  0.025570
# Amp5  -3.2634    21.6210 -0.999858  2.021138e-06  0.031703
# Amp9  -3.3569    22.3107 -0.999738  5.101337e-06  0.044405
# Amp10 -3.3289    22.1531 -0.999878  1.613339e-06  0.029998

# %%
label_line_1 = r'$y={0:.1f}x+{1:.1f}'.format(stats_list[0][0],stats_list[0][1])
label_line_4 = r'$y={0:.1f}x+{1:.1f}'.format(stats_list[1][0],stats_list[1][1])
label_line_5 = r'$y={0:.1f}x+{1:.1f}'.format(stats_list[2][0],stats_list[2][1])
label_line_9 = r'$y={0:.1f}x+{1:.1f}'.format(stats_list[3][0],stats_list[3][1])
label_line_10 = r'$y={0:.1f}x+{1:.1f}'.format(stats_list[4][0],stats_list[4][1])

# %%
print(label_line_1,
label_line_4,
label_line_5,
label_line_9,
label_line_10)
# Out:
# $y=-3.3x+22.0 $y=-3.3x+21.8 $y=-3.3x+21.6 $y=-3.4x+22.3 $y=-3.3x+22.2

# %%
## looping method starts here

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from scipy import stats

# %%
os.getcwd()
os.listdir()
df = pd.read_csv('compiled primer runs 2 to 5.csv')
df.head(20)
# Out:
#     Run   Amp      Conc      CT  Quantity
# 0     1  Amp1    1ng/ul  12.162    1000.0
# 1     1  Amp1  100pg/ul  15.335     100.0
# 2     1  Amp1   10pg/ul  18.688      10.0
# 3     1  Amp1    1pg/ul  22.037       1.0
# 4     1  Amp1  100fg/ul  25.357       0.1
# 5     1  Amp1       NTC   0.000       0.0
# 6     1  Amp2    1ng/ul  12.368    1000.0
# 7     1  Amp2  100pg/ul  15.536     100.0
# 8     1  Amp2   10pg/ul  18.903      10.0
# 9     1  Amp2    1pg/ul  22.237       1.0
# 10    1  Amp2  100fg/ul  25.537       0.1
# 11    1  Amp2       NTC   0.000       0.0
# 12    1  Amp3    1ng/ul  13.180    1000.0
# 13    1  Amp3  100pg/ul  16.427     100.0
# 14    1  Amp3   10pg/ul  19.794      10.0
# 15    1  Amp3    1pg/ul  23.280       1.0
# 16    1  Amp3  100fg/ul  26.639       0.1
# 17    1  Amp3       NTC   0.000       0.0
# 18    1  Amp4    1ng/ul  11.855    1000.0
# 19    1  Amp4  100pg/ul  15.052     100.0

# %%
df[df['Quantity'].isna()]
# Out:
#     Run   Amp Conc      CT  Quantity
# 71    2  Amp1  NTC  37.659       NaN
# 83    2  Amp4  NTC  35.764       NaN

# %%
df['Quantity'] = df['Quantity'].fillna(0)

# %%
df.isna().sum()
# not more na values
# Out:
# Run         0
# Amp         0
# Conc        0
# CT          0
# Quantity    0
# dtype: int64

# %%
df_no_ntc = df[(df['Conc'] != 'NTC') ]

# %%
df_no_ntc.head(10)
# Out:
#     Run   Amp      Conc      CT  Quantity
# 0     1  Amp1    1ng/ul  12.162    1000.0
# 1     1  Amp1  100pg/ul  15.335     100.0
# 2     1  Amp1   10pg/ul  18.688      10.0
# 3     1  Amp1    1pg/ul  22.037       1.0
# 4     1  Amp1  100fg/ul  25.357       0.1
# 6     1  Amp2    1ng/ul  12.368    1000.0
# 7     1  Amp2  100pg/ul  15.536     100.0
# 8     1  Amp2   10pg/ul  18.903      10.0
# 9     1  Amp2    1pg/ul  22.237       1.0
# 10    1  Amp2  100fg/ul  25.537       0.1

# %%
df_no_ntc['Quantity'] = np.log10(df_no_ntc['Quantity'])
# Out:
# <ipython-input-175-8d82a81e9f53>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_ntc['Quantity'] = np.log10(df_no_ntc['Quantity'])

# %%
df_no_ntc
# Out:
#      Run    Amp      Conc      CT  Quantity
# 0      1   Amp1    1ng/ul  12.162       3.0
# 1      1   Amp1  100pg/ul  15.335       2.0
# 2      1   Amp1   10pg/ul  18.688       1.0
# 3      1   Amp1    1pg/ul  22.037       0.0
# 4      1   Amp1  100fg/ul  25.357      -1.0
# ..   ...    ...       ...     ...       ...
# 233    4  Amp10   10pg/ul  18.896       1.0
# 234    4  Amp10    1pg/ul  22.586       0.0
# 235    4  Amp10    1pg/ul  22.633       0.0
# 236    4  Amp10  100fg/ul  26.324      -1.0
# 237    4  Amp10  100fg/ul  26.479      -1.0
#
# [200 rows x 5 columns]

# %%
# loop method to generate a dictionary of the DataFrame for each 'Amp'
# see 'manual filtering for Amp' step
# since we have Amp1,4,5,9, and 10, we cannot just use 'for amp in range()', because
# it will return us the values in chronological order. What we want is in the specific order
# of '1,4,5,9,10'

# so over here, we are creating

dict_amp = {}
for amp in [1,4,5,9,10]:
#range(0,len(df_withoutzero_quant_5amp['Amp'].unique())):
    print(amp)
    dict_amp['Amp'+str(amp)] = df_no_ntc[df_no_ntc['Amp']==('Amp'+str(amp))]

dict_amp['Amp4']
# Out:
# 1
# 4
# 5
# 9
# 10
#      Run   Amp      Conc      CT  Quantity
# 18     1  Amp4    1ng/ul  11.855       3.0
# 19     1  Amp4  100pg/ul  15.052       2.0
# 20     1  Amp4   10pg/ul  18.400       1.0
# 21     1  Amp4    1pg/ul  21.730       0.0
# 22     1  Amp4  100fg/ul  25.188      -1.0
# 72     2  Amp4    1ng/ul  12.275       3.0
# 73     2  Amp4    1ng/ul  12.147       3.0
# 74     2  Amp4  100pg/ul  15.239       2.0
# 75     2  Amp4  100pg/ul  15.242       2.0
# 76     2  Amp4   10pg/ul  18.957       1.0
# 77     2  Amp4   10pg/ul  19.136       1.0
# 78     2  Amp4    1pg/ul  21.955       0.0
# 79     2  Amp4    1pg/ul  21.989       0.0
# 80     2  Amp4  100fg/ul  25.667      -1.0
# 81     2  Amp4  100fg/ul  26.271      -1.0
# 132    3  Amp4    1ng/ul  11.972       3.0
# 133    3  Amp4    1ng/ul  11.887       3.0
# 134    3  Amp4  100pg/ul  15.447       2.0
# 135    3  Amp4  100pg/ul  15.417       2.0
# 136    3  Amp4   10pg/ul  19.299       1.0
# 137    3  Amp4   10pg/ul  19.345       1.0
# 138    3  Amp4    1pg/ul  22.397       0.0
# 139    3  Amp4    1pg/ul  21.897       0.0
# 140    3  Amp4  100fg/ul  25.572      -1.0
# 141    3  Amp4  100fg/ul  24.671      -1.0
# 192    4  Amp4    1ng/ul  11.957       3.0
# 193    4  Amp4    1ng/ul  11.779       3.0
# 194    4  Amp4  100pg/ul  15.264       2.0
# 195    4  Amp4  100pg/ul  15.186       2.0
# 196    4  Amp4   10pg/ul  18.604       1.0
# 197    4  Amp4   10pg/ul  18.677       1.0
# 198    4  Amp4    1pg/ul  22.253       0.0
# 199    4  Amp4    1pg/ul  22.289       0.0
# 200    4  Amp4  100fg/ul  26.139      -1.0
# 201    4  Amp4  100fg/ul  25.926      -1.0

# %%
stats_list = []
def get_stats(dict_amp):
    slope, intercept, r_value, p_value, std_err = stats.linregress(
    dict_amp.groupby(by=['Run','Conc']).mean().xs(key=1,level='Run')['Quantity'],
    dict_amp.groupby(by=['Run','Conc']).mean().xs(key=1,level='Run')['CT'])
    stats_list.append([slope, intercept, r_value, p_value, std_err])

# %%
stats_list = []
index_names = []
for amp in [1,4,5,9,10]:
    print('Amp'+str(amp))
    get_stats(dict_amp['Amp'+str(amp)])
    index_names.append('Amp'+str(amp))
# Out:
# Amp1
# Amp4
# Amp5
# Amp9
# Amp10

# %%
stats_list
# Out:
# [[-3.3092,
#   22.025000000000002,
#   -0.9999509825489866,
#   4.1196161252300284e-07,
#   0.018917716564075492],
#  [-3.3343999999999996,
#   21.7794,
#   -0.9999118033317193,
#   9.942746827808058e-07,
#   0.02556977382250136],
#  [-3.2634000000000003,
#   21.621,
#   -0.9998584703140501,
#   2.021137927366622e-06,
#   0.03170257613085176],
#  [-3.3569000000000004,
#   22.3107,
#   -0.999737631611078,
#   5.101337155173037e-06,
#   0.04440521741116426],
#  [-3.3289000000000004,
#   22.153100000000002,
#   -0.9998782133052824,
#   1.613339212066037e-06,
#   0.029998166610645714]]

# %%
pd.DataFrame(stats_list,index = index_names,
             columns = ['slope','intercept','r_value', 'p_value', 'std_err'])
# Out:
#         slope  intercept   r_value       p_value   std_err
# Amp1  -3.3092    22.0250 -0.999951  4.119616e-07  0.018918
# Amp4  -3.3344    21.7794 -0.999912  9.942747e-07  0.025570
# Amp5  -3.2634    21.6210 -0.999858  2.021138e-06  0.031703
# Amp9  -3.3569    22.3107 -0.999738  5.101337e-06  0.044405
# Amp10 -3.3289    22.1531 -0.999878  1.613339e-06  0.029998
