# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from scipy import stats

# %%
df = pd.read_csv('Lplasmid compiled stds.csv')

# %%
df = df[df['Conc (fg/ul)'] != 0]

# %%
df[(df['CT']=='Undetermined') | (df['CT']==0)]
# Out:
# Empty DataFrame
# Columns: [Run, Amp, Conc (fg/ul), CT]
# Index: []

# %%
df['CT'] = df['CT'].astype(float)

# %%
df = df[(df['CT']!='Undetermined') & (df['CT']!=0)]

# %%
df[(df['CT']=='Undetermined') | (df['CT']==0)]
# Out:
# Empty DataFrame
# Columns: [Run, Amp, Conc (fg/ul), CT]
# Index: []

# %%
df['Conc (pg/ul)'] = df['Conc (fg/ul)']/1000

# %%
df['Quantity'] = np.log10(df['Conc (pg/ul)'])

# %%
df.head(10)
# Out:
#    Run  Amp  Conc (fg/ul)      CT  Conc (pg/ul)  Quantity
# 0    1    2     1000000.0   8.770        1000.0       3.0
# 1    1    2     1000000.0   8.830        1000.0       3.0
# 2    1    2      100000.0  12.457         100.0       2.0
# 3    1    2      100000.0  12.572         100.0       2.0
# 4    1    2       10000.0  15.717          10.0       1.0
# 5    1    2       10000.0  15.664          10.0       1.0
# 6    1    2        1000.0  18.950           1.0       0.0
# 7    1    2        1000.0  18.975           1.0       0.0
# 8    1    2         100.0  22.889           0.1      -1.0
# 9    1    2         100.0  22.831           0.1      -1.0

# %%
df = df.sort_values(by=['Amp','Run','Quantity'],ascending=True)

# %%
df_grp = df.groupby(by=['Amp','Run','Quantity']).agg({'CT':['mean','std','count']},)

# %%
df_grp.round(decimals=3)
# Out:
#                       CT
#                     mean    std count
# Amp Run Quantity
# 1   2   -1.0      31.675  0.386     2
#          0.0      28.205  0.030     2
#          1.0      24.684  0.161     2
#          2.0      21.321  0.009     2
#          3.0      17.842  0.022     2
# ...                  ...    ...   ...
# 10  11  -3.0      28.908  0.219     2
#         -2.0      26.423  0.082     2
#         -1.0      23.353  0.034     2
#          1.0      18.215  0.054     2
#          2.0      12.252  0.058     2
#
# [256 rows x 3 columns]

# %%
amps = df_grp.index.get_level_values(0).unique()
dict_amp = {}
for amp in amps:
    print('Amplicon ' + str(amp))
    dict_amp['Amp'+str(amp)] = df_grp.loc[df_grp.index.get_level_values(0) == amp]
    print(dict_amp['Amp'+str(amp)])
# Out:
# Amplicon 1
#                          CT
#                        mean       std count
# Amp Run Quantity
# 1   2   -1.0      31.675000  0.386080     2
#          0.0      28.205000  0.029698     2
#          1.0      24.684500  0.160513     2
#          2.0      21.320500  0.009192     2
#          3.0      17.842500  0.021920     2
#     4   -4.0      38.422500  0.012021     2
#         -3.0      36.570000       NaN     1
#          0.0      27.863667  0.101943     3
#          2.0      20.861000  0.107764     3
#     5   -3.0      38.394000       NaN     1
#         -2.0      35.767000       NaN     1
#         -1.0      31.177000       NaN     1
#          0.0      28.044000       NaN     1
#          1.0      24.715000       NaN     1
#          2.0      20.981000       NaN     1
#          3.0      17.267000       NaN     1
#     6   -2.0      36.821000  0.272345     3
#         -1.0      33.216333  0.409346     3
#          0.0      30.650333  0.153871     3
#          1.0      26.521667  0.191858     3
#          2.0      23.605667  0.218065     3
#     8   -2.0      34.889000  0.585484     2
#         -1.0      31.278500  0.310420     2
#          0.0      28.958500  0.020506     2
#          1.0      24.410000  0.149907     2
#          2.0      21.134500  0.102530     2
# Amplicon 2
#                          CT
#                        mean       std count
# Amp Run Quantity
# 2   1   -1.0      22.860000  0.041012     2
#          0.0      18.962500  0.017678     2
#          1.0      15.690500  0.037477     2
#          2.0      12.514500  0.081317     2
#          3.0       8.800000  0.042426     2
#     4   -5.0      34.716000  0.551343     3
#         -4.0      32.050000  0.229678     3
#         -3.0      28.631333  0.013868     3
#          0.0      18.637667  0.023438     3
#          2.0      11.918333  0.010786     3
#     5   -5.0      36.616000       NaN     1
#         -4.0      32.336000       NaN     1
#         -3.0      28.585000       NaN     1
#         -2.0      25.457000       NaN     1
#         -1.0      21.629000       NaN     1
#          0.0      19.039000       NaN     1
#          1.0      15.679000       NaN     1
#          2.0      12.260000       NaN     1
#          3.0       8.156000       NaN     1
#     6   -2.0      27.458333  0.028361     3
#         -1.0      24.009000  0.015100     3
#          0.0      21.479000  0.017776     3
#          1.0      17.286000  0.011358     3
#          2.0      14.504000  0.013528     3
#     8   -2.0      25.749000  0.009899     2
#         -1.0      21.846500  0.020506     2
#          0.0      20.007500  0.054447     2
#          1.0      15.032000  0.066468     2
#          2.0      11.829500  0.036062     2
#     9   -2.0      26.893500  0.225567     2
#         -1.0      24.203000  0.132936     2
#          0.0      20.905500  0.111016     2
#          1.0      16.809000  0.189505     2
#          2.0      12.992000  0.261630     2
#     10  -2.0      28.062000  0.094752     2
#         -1.0      24.398000  0.181019     2
#          0.0      20.823000  0.233345     2
#          1.0      18.009500  0.152028     2
#          2.0      14.032500  0.160513     2
#     11  -2.0      28.354500  0.688015     2
#         -1.0      25.309000  0.098995     2
#          0.0      21.421500  0.125158     2
#          1.0      18.540500  0.210011     2
#          2.0      14.024500  0.067175     2
# Amplicon 3
#                        CT
#                      mean       std count
# Amp Run Quantity
# 3   1   -1.0      23.1570  0.033941     2
#          0.0      17.7395  2.288905     2
#          1.0      16.1415  0.012021     2
#          2.0      12.6250  0.009899     2
#          3.0       9.2375  0.031820     2
# Amplicon 4
#                          CT
#                        mean       std count
# Amp Run Quantity
# 4   1   -1.0      21.869000  0.012728     2
#          0.0      18.505500  0.016263     2
#          1.0      15.326000  0.009899     2
#          2.0      11.813500  0.045962     2
#          3.0       8.400000  0.070711     2
#     3   -6.0      38.607000  1.025305     2
#         -5.0      35.374000  0.122854     3
#         -4.0      32.246000  0.114293     3
#         -3.0      28.883667  0.021595     3
#         -2.0      25.403667  0.032808     3
#         -1.0      22.033333  0.021502     3
#          0.0      18.740667  0.002887     3
#          1.0      15.434333  0.021733     3
#          2.0      12.103333  0.011719     3
#          3.0       8.674667  0.026839     3
#     5   -5.0      36.896000       NaN     1
#         -4.0      32.144000       NaN     1
#         -3.0      28.107000       NaN     1
#         -2.0      25.142000       NaN     1
#         -1.0      21.265000       NaN     1
#          0.0      18.573000       NaN     1
#          1.0      15.299000       NaN     1
#          2.0      11.825000       NaN     1
#          3.0       7.772000       NaN     1
#     6   -2.0      26.867667  0.088951     3
#         -1.0      23.404333  0.208097     3
#          0.0      20.881333  0.076514     3
#          1.0      16.650667  0.184893     3
#          2.0      13.905333  0.112838     3
#     8   -2.0      25.468000  0.156978     2
#         -1.0      21.529000  0.168291     2
#          0.0      19.688500  0.170413     2
#          1.0      14.722500  0.170413     2
#          2.0      11.581000  0.212132     2
#     9   -2.0      26.612500  0.019092     2
#         -1.0      23.948500  0.031820     2
#          0.0      20.640500  0.038891     2
#          1.0      16.504000  0.024042     2
#          2.0      12.705500  0.068589     2
#     10  -2.0      27.674000  0.019799     2
#         -1.0      23.991000  0.009899     2
#          0.0      20.497500  0.061518     2
#          1.0      17.654000  0.089095     2
#          2.0      13.665500  0.010607     2
#     11  -2.0      27.921500  0.012021     2
#         -1.0      24.890000  0.015556     2
#          0.0      21.032000  0.008485     2
#          1.0      18.151500  0.079903     2
#          2.0      13.676000  0.039598     2
# Amplicon 5
#                          CT
#                        mean       std count
# Amp Run Quantity
# 5   1   -1.0      22.000000  0.002828     2
#          0.0      18.615000  0.117380     2
#          1.0      15.350500  0.010607     2
#          2.0      11.874000  0.145664     2
#          3.0       8.436000  0.100409     2
#     5   -5.0      36.313000       NaN     1
#         -4.0      32.144000       NaN     1
#         -3.0      28.217000       NaN     1
#         -2.0      25.181000       NaN     1
#         -1.0      21.405000       NaN     1
#          0.0      18.693000       NaN     1
#          1.0      15.376000       NaN     1
#          2.0      11.846000       NaN     1
#          3.0       7.717000       NaN     1
#     7   -2.0      25.549667  0.184625     3
#         -1.0      22.153667  0.157090     3
#          0.0      19.119333  0.187239     3
#          1.0      15.604000  0.142243     3
#          2.0      12.078667  0.226341     3
#     8   -2.0      25.537000  0.220617     2
#         -1.0      22.687500  0.133643     2
#          0.0      19.261000  0.120208     2
#          1.0      16.123000  0.072125     2
#          2.0      12.581000  0.141421     2
#     9   -2.0      26.866500  0.098288     2
#         -1.0      24.155500  0.127986     2
#          0.0      20.838500  0.228395     2
#          1.0      16.743000  0.209304     2
#          2.0      12.776000  0.066468     2
#     10  -2.0      27.928500  0.031820     2
#         -1.0      24.167500  0.033234     2
#          0.0      20.597000  0.063640     2
#          1.0      17.807000  0.012728     2
#          2.0      13.767500  0.014849     2
#     11  -2.0      28.211500  0.150614     2
#         -1.0      25.133500  0.106773     2
#          0.0      21.370000  0.227688     2
#          1.0      18.408500  0.123744     2
#          2.0      13.998000  0.188090     2
# Amplicon 7
#                          CT
#                        mean       std count
# Amp Run Quantity
# 7   1   -1.0      22.061000  0.002828     2
#          0.0      18.903000  0.052326     2
#          1.0      15.186500  0.002121     2
#          2.0      12.037000  0.043841     2
#          3.0       8.522000  0.032527     2
#     4   -5.0      35.782000  0.369903     3
#         -4.0      31.908000  0.307937     3
#         -3.0      28.437667  0.125049     3
#          0.0      18.427667  0.145139     3
#          2.0      11.612000  0.237994     3
#     5   -5.0      34.682000       NaN     1
#         -4.0      32.024000       NaN     1
#         -3.0      28.424000       NaN     1
#         -2.0      25.295000       NaN     1
#         -1.0      21.473000       NaN     1
#          0.0      18.634000       NaN     1
#          1.0      15.405000       NaN     1
#          2.0      11.876000       NaN     1
#          3.0       7.828000       NaN     1
#     7   -2.0      25.485333  0.017098     3
#         -1.0      22.163000  0.084788     3
#          0.0      19.119000  0.010000     3
#          1.0      15.417667  0.172077     3
#          2.0      11.924667  0.041405     3
#     8   -2.0      25.708500  0.194454     2
#         -1.0      22.723500  0.009192     2
#          0.0      19.246500  0.045962     2
#          1.0      16.144000  0.016971     2
#          2.0      12.665500  0.146371     2
#     9   -2.0      25.794000  0.210718     2
#         -1.0      22.365500  0.211425     2
#          0.0      19.454000  0.132936     2
#          1.0      15.640000  0.159806     2
#          2.0      11.901000  0.220617     2
#     10  -2.0      27.949000  0.029698     2
#         -1.0      24.237500  0.013435     2
#          0.0      20.652000  0.062225     2
#          1.0      17.811000  0.048083     2
#          2.0      13.764000  0.074953     2
#     11  -4.0      33.383000  0.151321     2
#         -3.0      28.922500  0.263751     2
#         -2.0      26.308500  0.026163     2
#          0.0      22.443000  1.316633     2
#          2.0      12.071500  0.004950     2
# Amplicon 8
#                        CT
#                      mean       std count
# Amp Run Quantity
# 8   2   -1.0      23.9085  0.053033     2
#          0.0      20.5255  0.019092     2
#          1.0      17.0935  0.027577     2
#          2.0      13.6540  0.028284     2
#          3.0       9.9950  0.046669     2
# Amplicon 9
#                        CT
#                      mean       std count
# Amp Run Quantity
# 9   2   -1.0      22.3055  0.007778     2
#          0.0      18.9285  0.012021     2
#          1.0      15.5600  0.046669     2
#          2.0      12.1270  0.002828     2
#          3.0       8.5305  0.009192     2
# Amplicon 10
#                          CT
#                        mean       std count
# Amp Run Quantity
# 10  2   -1.0      22.397500  0.176070     2
#          0.0      18.909000  0.055154     2
#          1.0      15.642000  0.149907     2
#          2.0      12.242500  0.478711     2
#          3.0       8.678500  0.276479     2
#     5   -5.0      36.293000       NaN     1
#         -4.0      33.284000       NaN     1
#         -3.0      28.686000       NaN     1
#         -2.0      25.713000       NaN     1
#         -1.0      21.862000       NaN     1
#          0.0      19.157000       NaN     1
#          1.0      15.836000       NaN     1
#          2.0      12.528000       NaN     1
#          3.0       8.266000       NaN     1
#     7   -2.0      25.699000  0.065092     3
#         -1.0      22.291333  0.062083     3
#          0.0      19.333000  0.033779     3
#          1.0      15.796667  0.107058     3
#          2.0      12.276000  0.055073     3
#     8   -2.0      25.959500  0.154856     2
#         -1.0      23.064500  0.225567     2
#          0.0      19.660500  0.152028     2
#          1.0      16.584000  0.173948     2
#          2.0      13.089500  0.152028     2
#     9   -2.0      26.270000  0.229103     2
#         -1.0      22.798500  0.154856     2
#          0.0      19.966500  0.183141     2
#          1.0      16.229500  0.142128     2
#          2.0      12.499000  0.181019     2
#     10  -2.0      28.257500  0.135057     2
#         -1.0      24.572500  0.205768     2
#          0.0      21.065000  0.224860     2
#          1.0      18.259500  0.146371     2
#          2.0      14.178000  0.135765     2
#     11  -3.0      28.908000  0.219203     2
#         -2.0      26.423000  0.082024     2
#         -1.0      23.353000  0.033941     2
#          1.0      18.215000  0.053740     2
#          2.0      12.252000  0.057983     2

# %%
dict_amp
# Out:
# {'Amp1':                          CT
#                         mean       std count
#  Amp Run Quantity
#  1   2   -1.0      31.675000  0.386080     2
#           0.0      28.205000  0.029698     2
#           1.0      24.684500  0.160513     2
#           2.0      21.320500  0.009192     2
#           3.0      17.842500  0.021920     2
#      4   -4.0      38.422500  0.012021     2
#          -3.0      36.570000       NaN     1
#           0.0      27.863667  0.101943     3
#           2.0      20.861000  0.107764     3
#      5   -3.0      38.394000       NaN     1
#          -2.0      35.767000       NaN     1
#          -1.0      31.177000       NaN     1
#           0.0      28.044000       NaN     1
#           1.0      24.715000       NaN     1
#           2.0      20.981000       NaN     1
#           3.0      17.267000       NaN     1
#      6   -2.0      36.821000  0.272345     3
#          -1.0      33.216333  0.409346     3
#           0.0      30.650333  0.153871     3
#           1.0      26.521667  0.191858     3
#           2.0      23.605667  0.218065     3
#      8   -2.0      34.889000  0.585484     2
#          -1.0      31.278500  0.310420     2
#           0.0      28.958500  0.020506     2
#           1.0      24.410000  0.149907     2
#           2.0      21.134500  0.102530     2,
#  'Amp2':                          CT
#                         mean       std count
#  Amp Run Quantity
#  2   1   -1.0      22.860000  0.041012     2
#           0.0      18.962500  0.017678     2
#           1.0      15.690500  0.037477     2
#           2.0      12.514500  0.081317     2
#           3.0       8.800000  0.042426     2
#      4   -5.0      34.716000  0.551343     3
#          -4.0      32.050000  0.229678     3
#          -3.0      28.631333  0.013868     3
#           0.0      18.637667  0.023438     3
#           2.0      11.918333  0.010786     3
#      5   -5.0      36.616000       NaN     1
#          -4.0      32.336000       NaN     1
#          -3.0      28.585000       NaN     1
#          -2.0      25.457000       NaN     1
#          -1.0      21.629000       NaN     1
#           0.0      19.039000       NaN     1
#           1.0      15.679000       NaN     1
#           2.0      12.260000       NaN     1
#           3.0       8.156000       NaN     1
#      6   -2.0      27.458333  0.028361     3
#          -1.0      24.009000  0.015100     3
#           0.0      21.479000  0.017776     3
#           1.0      17.286000  0.011358     3
#           2.0      14.504000  0.013528     3
#      8   -2.0      25.749000  0.009899     2
#          -1.0      21.846500  0.020506     2
#           0.0      20.007500  0.054447     2
#           1.0      15.032000  0.066468     2
#           2.0      11.829500  0.036062     2
#      9   -2.0      26.893500  0.225567     2
#          -1.0      24.203000  0.132936     2
#           0.0      20.905500  0.111016     2
#           1.0      16.809000  0.189505     2
#           2.0      12.992000  0.261630     2
#      10  -2.0      28.062000  0.094752     2
#          -1.0      24.398000  0.181019     2
#           0.0      20.823000  0.233345     2
#           1.0      18.009500  0.152028     2
#           2.0      14.032500  0.160513     2
#      11  -2.0      28.354500  0.688015     2
#          -1.0      25.309000  0.098995     2
#           0.0      21.421500  0.125158     2
#           1.0      18.540500  0.210011     2
#           2.0      14.024500  0.067175     2,
#  'Amp3':                        CT
#                       mean       std count
#  Amp Run Quantity
#  3   1   -1.0      23.1570  0.033941     2
#           0.0      17.7395  2.288905     2
#           1.0      16.1415  0.012021     2
#           2.0      12.6250  0.009899     2
#           3.0       9.2375  0.031820     2,
#  'Amp4':                          CT
#                         mean       std count
#  Amp Run Quantity
#  4   1   -1.0      21.869000  0.012728     2
#           0.0      18.505500  0.016263     2
#           1.0      15.326000  0.009899     2
#           2.0      11.813500  0.045962     2
#           3.0       8.400000  0.070711     2
#      3   -6.0      38.607000  1.025305     2
#          -5.0      35.374000  0.122854     3
#          -4.0      32.246000  0.114293     3
#          -3.0      28.883667  0.021595     3
#          -2.0      25.403667  0.032808     3
#          -1.0      22.033333  0.021502     3
#           0.0      18.740667  0.002887     3
#           1.0      15.434333  0.021733     3
#           2.0      12.103333  0.011719     3
#           3.0       8.674667  0.026839     3
#      5   -5.0      36.896000       NaN     1
#          -4.0      32.144000       NaN     1
#          -3.0      28.107000       NaN     1
#          -2.0      25.142000       NaN     1
#          -1.0      21.265000       NaN     1
#           0.0      18.573000       NaN     1
#           1.0      15.299000       NaN     1
#           2.0      11.825000       NaN     1
#           3.0       7.772000       NaN     1
#      6   -2.0      26.867667  0.088951     3
#          -1.0      23.404333  0.208097     3
#           0.0      20.881333  0.076514     3
#           1.0      16.650667  0.184893     3
#           2.0      13.905333  0.112838     3
#      8   -2.0      25.468000  0.156978     2
#          -1.0      21.529000  0.168291     2
#           0.0      19.688500  0.170413     2
#           1.0      14.722500  0.170413     2
#           2.0      11.581000  0.212132     2
#      9   -2.0      26.612500  0.019092     2
#          -1.0      23.948500  0.031820     2
#           0.0      20.640500  0.038891     2
#           1.0      16.504000  0.024042     2
#           2.0      12.705500  0.068589     2
#      10  -2.0      27.674000  0.019799     2
#          -1.0      23.991000  0.009899     2
#           0.0      20.497500  0.061518     2
#           1.0      17.654000  0.089095     2
#           2.0      13.665500  0.010607     2
#      11  -2.0      27.921500  0.012021     2
#          -1.0      24.890000  0.015556     2
#           0.0      21.032000  0.008485     2
#           1.0      18.151500  0.079903     2
#           2.0      13.676000  0.039598     2,
#  'Amp5':                          CT
#                         mean       std count
#  Amp Run Quantity
#  5   1   -1.0      22.000000  0.002828     2
#           0.0      18.615000  0.117380     2
#           1.0      15.350500  0.010607     2
#           2.0      11.874000  0.145664     2
#           3.0       8.436000  0.100409     2
#      5   -5.0      36.313000       NaN     1
#          -4.0      32.144000       NaN     1
#          -3.0      28.217000       NaN     1
#          -2.0      25.181000       NaN     1
#          -1.0      21.405000       NaN     1
#           0.0      18.693000       NaN     1
#           1.0      15.376000       NaN     1
#           2.0      11.846000       NaN     1
#           3.0       7.717000       NaN     1
#      7   -2.0      25.549667  0.184625     3
#          -1.0      22.153667  0.157090     3
#           0.0      19.119333  0.187239     3
#           1.0      15.604000  0.142243     3
#           2.0      12.078667  0.226341     3
#      8   -2.0      25.537000  0.220617     2
#          -1.0      22.687500  0.133643     2
#           0.0      19.261000  0.120208     2
#           1.0      16.123000  0.072125     2
#           2.0      12.581000  0.141421     2
#      9   -2.0      26.866500  0.098288     2
#          -1.0      24.155500  0.127986     2
#           0.0      20.838500  0.228395     2
#           1.0      16.743000  0.209304     2
#           2.0      12.776000  0.066468     2
#      10  -2.0      27.928500  0.031820     2
#          -1.0      24.167500  0.033234     2
#           0.0      20.597000  0.063640     2
#           1.0      17.807000  0.012728     2
#           2.0      13.767500  0.014849     2
#      11  -2.0      28.211500  0.150614     2
#          -1.0      25.133500  0.106773     2
#           0.0      21.370000  0.227688     2
#           1.0      18.408500  0.123744     2
#           2.0      13.998000  0.188090     2,
#  'Amp7':                          CT
#                         mean       std count
#  Amp Run Quantity
#  7   1   -1.0      22.061000  0.002828     2
#           0.0      18.903000  0.052326     2
#           1.0      15.186500  0.002121     2
#           2.0      12.037000  0.043841     2
#           3.0       8.522000  0.032527     2
#      4   -5.0      35.782000  0.369903     3
#          -4.0      31.908000  0.307937     3
#          -3.0      28.437667  0.125049     3
#           0.0      18.427667  0.145139     3
#           2.0      11.612000  0.237994     3
#      5   -5.0      34.682000       NaN     1
#          -4.0      32.024000       NaN     1
#          -3.0      28.424000       NaN     1
#          -2.0      25.295000       NaN     1
#          -1.0      21.473000       NaN     1
#           0.0      18.634000       NaN     1
#           1.0      15.405000       NaN     1
#           2.0      11.876000       NaN     1
#           3.0       7.828000       NaN     1
#      7   -2.0      25.485333  0.017098     3
#          -1.0      22.163000  0.084788     3
#           0.0      19.119000  0.010000     3
#           1.0      15.417667  0.172077     3
#           2.0      11.924667  0.041405     3
#      8   -2.0      25.708500  0.194454     2
#          -1.0      22.723500  0.009192     2
#           0.0      19.246500  0.045962     2
#           1.0      16.144000  0.016971     2
#           2.0      12.665500  0.146371     2
#      9   -2.0      25.794000  0.210718     2
#          -1.0      22.365500  0.211425     2
#           0.0      19.454000  0.132936     2
#           1.0      15.640000  0.159806     2
#           2.0      11.901000  0.220617     2
#      10  -2.0      27.949000  0.029698     2
#          -1.0      24.237500  0.013435     2
#           0.0      20.652000  0.062225     2
#           1.0      17.811000  0.048083     2
#           2.0      13.764000  0.074953     2
#      11  -4.0      33.383000  0.151321     2
#          -3.0      28.922500  0.263751     2
#          -2.0      26.308500  0.026163     2
#           0.0      22.443000  1.316633     2
#           2.0      12.071500  0.004950     2,
#  'Amp8':                        CT
#                       mean       std count
#  Amp Run Quantity
#  8   2   -1.0      23.9085  0.053033     2
#           0.0      20.5255  0.019092     2
#           1.0      17.0935  0.027577     2
#           2.0      13.6540  0.028284     2
#           3.0       9.9950  0.046669     2,
#  'Amp9':                        CT
#                       mean       std count
#  Amp Run Quantity
#  9   2   -1.0      22.3055  0.007778     2
#           0.0      18.9285  0.012021     2
#           1.0      15.5600  0.046669     2
#           2.0      12.1270  0.002828     2
#           3.0       8.5305  0.009192     2,
#  'Amp10':                          CT
#                         mean       std count
#  Amp Run Quantity
#  10  2   -1.0      22.397500  0.176070     2
#           0.0      18.909000  0.055154     2
#           1.0      15.642000  0.149907     2
#           2.0      12.242500  0.478711     2
#           3.0       8.678500  0.276479     2
#      5   -5.0      36.293000       NaN     1
#          -4.0      33.284000       NaN     1
#          -3.0      28.686000       NaN     1
#          -2.0      25.713000       NaN     1
#          -1.0      21.862000       NaN     1
#           0.0      19.157000       NaN     1
#           1.0      15.836000       NaN     1
#           2.0      12.528000       NaN     1
#           3.0       8.266000       NaN     1
#      7   -2.0      25.699000  0.065092     3
#          -1.0      22.291333  0.062083     3
#           0.0      19.333000  0.033779     3
#           1.0      15.796667  0.107058     3
#           2.0      12.276000  0.055073     3
#      8   -2.0      25.959500  0.154856     2
#          -1.0      23.064500  0.225567     2
#           0.0      19.660500  0.152028     2
#           1.0      16.584000  0.173948     2
#           2.0      13.089500  0.152028     2
#      9   -2.0      26.270000  0.229103     2
#          -1.0      22.798500  0.154856     2
#           0.0      19.966500  0.183141     2
#           1.0      16.229500  0.142128     2
#           2.0      12.499000  0.181019     2
#      10  -2.0      28.257500  0.135057     2
#          -1.0      24.572500  0.205768     2
#           0.0      21.065000  0.224860     2
#           1.0      18.259500  0.146371     2
#           2.0      14.178000  0.135765     2
#      11  -3.0      28.908000  0.219203     2
#          -2.0      26.423000  0.082024     2
#          -1.0      23.353000  0.033941     2
#           1.0      18.215000  0.053740     2
#           2.0      12.252000  0.057983     2}

# %%
# testing syntax to get the quantity
dict_amp['Amp1'].index.get_level_values(2)
# Out:
# Float64Index([-1.0,  0.0,  1.0,  2.0,  3.0, -4.0, -3.0,  0.0,  2.0, -3.0, -2.0,
#               -1.0,  0.0,  1.0,  2.0,  3.0, -2.0, -1.0,  0.0,  1.0,  2.0, -2.0,
#               -1.0,  0.0,  1.0,  2.0],
#              dtype='float64', name='Quantity')

# %%
# testing syntax to get the mean CT value for each amp per run (here it's amp1, run2)
dict_amp['Amp1'].loc[1,2]['CT']['mean']
# Out:
# Quantity
# -1.0    31.6750
#  0.0    28.2050
#  1.0    24.6845
#  2.0    21.3205
#  3.0    17.8425
# Name: mean, dtype: float64

# %%
# testing syntax to get the quantity for each amp per run (here it's amp1, run2)
dict_amp['Amp1'].loc[1,2].index
# Out:
# Float64Index([-1.0, 0.0, 1.0, 2.0, 3.0], dtype='float64', name='Quantity')

# %%
# testing syntax because there is some disagreement in the manually calcualted slope and the one in python
# turns out that the x and y values for the stats.linregress are swapped
y = [31.6750,28.2050,24.6845,21.3205,17.8425]
x = [-1,0,1,2,3]

# %%
# testing syntax to extract the number in Amp1, Amp2,..., Amp10
int(re.findall(r"\d+", "Amp1")[0])
# Out:
# 1

# %%
# testing syntax to return the linear regression statistics using the syntax to extract the numbers
run_num = 2
slope, intercept, r_value, p_value, std_err = stats.linregress(
    x = dict_amp['Amp1'].loc[int(re.findall(r"\d+", "Amp1")[0]),run_num].index,#['CT']['mean'],
    y = dict_amp['Amp1'].loc[int(re.findall(r"\d+", "Amp1")[0]),run_num]['CT']['mean']
)

# %%
# correct value
slope,intercept
# Out:
# (-3.4549499999999997, 28.20045)

# %%
dict_amp['Amp1'].loc[1,4].index
# Out:
# pandas.core.indexes.numeric.Float64Index

# %%
dict_amp['Amp1']['CT']['mean']
# Out:
# Amp  Run  Quantity
# 1    2    -1.0        31.675000
#            0.0        28.205000
#            1.0        24.684500
#            2.0        21.320500
#            3.0        17.842500
#      4    -4.0        38.422500
#           -3.0        36.570000
#            0.0        27.863667
#            2.0        20.861000
#      5    -3.0        38.394000
#           -2.0        35.767000
#           -1.0        31.177000
#            0.0        28.044000
#            1.0        24.715000
#            2.0        20.981000
#            3.0        17.267000
#      6    -2.0        36.821000
#           -1.0        33.216333
#            0.0        30.650333
#            1.0        26.521667
#            2.0        23.605667
#      8    -2.0        34.889000
#           -1.0        31.278500
#            0.0        28.958500
#            1.0        24.410000
#            2.0        21.134500
# Name: mean, dtype: float64

# %%
for n in dict_amp['Amp1'].index.get_level_values(1).unique():
    print(n)
# Out:
# 2
# 4
# 5
# 6
# 8

# %%
import re

# %%
int(re.findall(r"\d+", "6M1D14M")[0])
# Out:
# '6'

# %%
# here we are getting the linear regression statistics per amp per run and throwing it all into a list

reg_stat=[]
for amp in dict_amp:
    #print(amp)
    for run_num in dict_amp[amp].index.get_level_values(1).unique():
        #print('run number= '+str(run_num))
        #print(int(re.findall(r"\d+", amp)[0]))
        print(amp)
        print(run_num)
        #print(dict_amp[amp].loc[int(re.findall(r"\d+", amp)[0]),run_num]['CT']['mean'])
        #print(dict_amp[amp].loc[int(re.findall(r"\d+", amp)[0]),run_num].index)
        slope, intercept, r_value, p_value, std_err = stats.linregress(
            #x=dict_amp[amp].loc[1, 2].index,
            #y=dict_amp[amp].loc[1, 2]['CT']['mean']
            x = dict_amp[amp].loc[int(re.findall(r"\d+", amp)[0]),run_num].index,
            y = dict_amp[amp].loc[int(re.findall(r"\d+", amp)[0]),run_num]['CT']['mean']
        )
        print(slope, intercept, r_value, p_value, std_err)
        #run_number
        reg_stat.append((amp,run_num,slope, intercept, r_value, p_value, std_err))
# Out:
# Amp1
# 2
# -3.4549499999999997 28.20045 -0.9999787616251801 1.1749364996123588e-07 0.013000608960092053
# Amp1
# 4
# -2.9464413919413914 27.246239926739932 -0.996901101605613 0.0030988983943870396 0.1644041135989676
# Amp1
# 5
# -3.550535714285715 28.049285714285713 -0.9989842675301619 6.311982998020809e-08 0.07162169428208023
# Amp1
# 6
# -3.312533333333333 30.163 -0.9980986427791863 9.949597997457391e-05 0.11810451115666704
# Amp1
# 8
# -3.4377499999999994 28.1341 -0.9963074808266159 0.0002692013936240604 0.17103908666344872
# Amp2
# 1
# -3.4568 19.2223 -0.9993692172485391 1.901570691604717e-05 0.07092087139904178
# Amp2
# 4
# -3.2920784313725493 18.60650980392157 -0.9996843647838384 6.731184169463387e-06 0.047766134593394245
# Amp2
# 5
# -3.4383 18.756922222222222 -0.9989442123324903 1.25779314177506e-10 0.05976434188415773
# Amp2
# 6
# -3.2631666666666663 20.947266666666668 -0.9977120426967426 0.00013132778749456498 0.12766263846270526
# Amp2
# 8
# -3.465350000000001 18.8929 -0.9930618699398286 0.0006930188025331941 0.23691457497024535
# Amp2
# 9
# -3.5197000000000003 20.3606 -0.9969186999167788 0.00020522677496759528 0.15989411079420093
# Amp2
# 10
# -3.44475 21.065 -0.9989290514252089 4.206462338283449e-05 0.09211819852775968
# Amp2
# 11
# -3.54285 21.530000000000005 -0.9975464902466367 0.0001458329443455281 0.14354938464979589
# Amp3
# 1
# -3.29535 19.07545 -0.9884374521583013 0.0014899081787325818 0.2918599250211193
# Amp4
# 1
# -3.3629999999999995 18.545799999999996 -0.9998807425965324 1.563342420782085e-06 0.02998905355848938
# Amp4
# 3
# -3.3342020202020204 18.74876363636363 -0.9999587453143681 1.2672131921249355e-17 0.010708089526513299
# Amp4
# 5
# -3.493966666666666 18.397477777777777 -0.9982709816732711 7.064889330078908e-10 0.07775857257220192
# Amp4
# 6
# -3.2678333333333343 20.341866666666668 -0.9975631231493708 0.0001443528687173971 0.1319550246050414
# Amp4
# 8
# -3.45805 18.5978 -0.9931569916955207 0.0006788255402313769 0.23477239154835286
# Amp4
# 9
# -3.52585 20.0822 -0.9967666610252864 0.0002205971860090647 0.16409637158288246
# Amp4
# 10
# -3.4354 20.696399999999997 -0.9989388475750295 4.148884777055433e-05 0.09144635950472092
# Amp4
# 11
# -3.5229500000000002 21.1342 -0.997617954060944 0.00013950951197465493 0.14064130201805283
# Amp5
# 1
# -3.3869000000000002 18.642 -0.9999444253542447 4.973307260996524e-07 0.02061641740621164
# Amp5
# 5
# -3.4574666666666665 18.419422222222224 -0.9990066624702224 1.0161469267451176e-10 0.05829027980356226
# Amp5
# 7
# -3.349166666666667 18.901066666666665 -0.9996545145849337 7.708252399844451e-06 0.05084152210909875
# Amp5
# 8
# -3.24765 19.2379 -0.999414820138052 1.699142453197495e-05 0.06417397577419494
# Amp5
# 9
# -3.5593500000000007 20.2759 -0.9966856509949539 0.00022893657779857548 0.16772810090540338
# Amp5
# 10
# -3.46825 20.8535 -0.9987180852317763 5.508572336353679e-05 0.10148741711825107
# Amp5
# 11
# -3.5152 21.424300000000002 -0.9979593145184742 0.00011062798091554517 0.12985477786101313
# Amp7
# 1
# -3.3944000000000005 18.7363 -0.9997146947988272 5.784686189134448e-06 0.046823640752633726
# Amp7
# 4
# -3.4204803921568625 18.39250588235294 -0.9997967027511707 3.4795082099465342e-06 0.03982662019010798
# Amp7
# 5
# -3.342650000000001 18.39523888888889 -0.9993559989685818 2.230324565517894e-11 0.045363860665700584
# Amp7
# 7
# -3.3866666666666667 18.821933333333334 -0.9994856300637184 1.400276215454998e-05 0.06273822155946142
# Amp7
# 8
# -3.266550000000001 19.297599999999996 -0.9996932385246048 6.4493374245728395e-06 0.04672443151070839
# Amp7
# 9
# -3.45115 19.0309 -0.9988793166947805 4.502826273100797e-05 0.09441150618436787
# Amp7
# 10
# -3.4796499999999995 20.882699999999996 -0.9988782885082855 4.509023769483296e-05 0.09523489819039196
# Amp7
# 11
# -3.292827586206897 20.015741379310345 -0.9829435627620712 0.0026671785190552936 0.3556961122736146
# Amp8
# 2
# -3.4698499999999997 20.50515 -0.9998912744553377 1.3608935708123016e-06 0.029543795174848824
# Amp9
# 2
# -3.43515 18.925449999999998 -0.9999107084921589 1.0128456699277827e-06 0.026505392533120873
# Amp10
# 2
# -3.4104500000000004 18.98435 -0.9999049170398376 1.1129655048695854e-06 0.02715491054423843
# Amp10
# 5
# -3.443866666666666 18.95891111111111 -0.9989670009050678 1.1653344753760995e-10 0.05921053013026515
# Amp10
# 7
# -3.3340666666666667 19.0792 -0.9995391952240218 1.1873514689354827e-05 0.058457100446328486
# Amp10
# 8
# -3.2220500000000003 19.6716 -0.999562819988769 1.0972253199488358e-05 0.05502489588055747
# Amp10
# 9
# -3.4111 19.552699999999998 -0.9988380268793627 4.753924388338694e-05 0.09502231316906506
# Amp10
# 10
# -3.4471999999999996 21.2665 -0.9987345556376485 5.402763870148474e-05 0.10022010776286876
# Amp10
# 11
# -3.181011627906977 19.921593023255813 -0.9879386473484756 0.0015872326652408325 0.28785524724379036

# %%
reg_stat
# Out:
# [('Amp1',
#   2,
#   -3.4549499999999997,
#   28.20045,
#   -0.9999787616251801,
#   1.1749364996123588e-07,
#   0.013000608960092053),
#  ('Amp1',
#   4,
#   -2.9464413919413914,
#   27.246239926739932,
#   -0.996901101605613,
#   0.0030988983943870396,
#   0.1644041135989676),
#  ('Amp1',
#   5,
#   -3.550535714285715,
#   28.049285714285713,
#   -0.9989842675301619,
#   6.311982998020809e-08,
#   0.07162169428208023),
#  ('Amp1',
#   6,
#   -3.312533333333333,
#   30.163,
#   -0.9980986427791863,
#   9.949597997457391e-05,
#   0.11810451115666704),
#  ('Amp1',
#   8,
#   -3.4377499999999994,
#   28.1341,
#   -0.9963074808266159,
#   0.0002692013936240604,
#   0.17103908666344872),
#  ('Amp2',
#   1,
#   -3.4568,
#   19.2223,
#   -0.9993692172485391,
#   1.901570691604717e-05,
#   0.07092087139904178),
#  ('Amp2',
#   4,
#   -3.2920784313725493,
#   18.60650980392157,
#   -0.9996843647838384,
#   6.731184169463387e-06,
#   0.047766134593394245),
#  ('Amp2',
#   5,
#   -3.4383,
#   18.756922222222222,
#   -0.9989442123324903,
#   1.25779314177506e-10,
#   0.05976434188415773),
#  ('Amp2',
#   6,
#   -3.2631666666666663,
#   20.947266666666668,
#   -0.9977120426967426,
#   0.00013132778749456498,
#   0.12766263846270526),
#  ('Amp2',
#   8,
#   -3.465350000000001,
#   18.8929,
#   -0.9930618699398286,
#   0.0006930188025331941,
#   0.23691457497024535),
#  ('Amp2',
#   9,
#   -3.5197000000000003,
#   20.3606,
#   -0.9969186999167788,
#   0.00020522677496759528,
#   0.15989411079420093),
#  ('Amp2',
#   10,
#   -3.44475,
#   21.065,
#   -0.9989290514252089,
#   4.206462338283449e-05,
#   0.09211819852775968),
#  ('Amp2',
#   11,
#   -3.54285,
#   21.530000000000005,
#   -0.9975464902466367,
#   0.0001458329443455281,
#   0.14354938464979589),
#  ('Amp3',
#   1,
#   -3.29535,
#   19.07545,
#   -0.9884374521583013,
#   0.0014899081787325818,
#   0.2918599250211193),
#  ('Amp4',
#   1,
#   -3.3629999999999995,
#   18.545799999999996,
#   -0.9998807425965324,
#   1.563342420782085e-06,
#   0.02998905355848938),
#  ('Amp4',
#   3,
#   -3.3342020202020204,
#   18.74876363636363,
#   -0.9999587453143681,
#   1.2672131921249355e-17,
#   0.010708089526513299),
#  ('Amp4',
#   5,
#   -3.493966666666666,
#   18.397477777777777,
#   -0.9982709816732711,
#   7.064889330078908e-10,
#   0.07775857257220192),
#  ('Amp4',
#   6,
#   -3.2678333333333343,
#   20.341866666666668,
#   -0.9975631231493708,
#   0.0001443528687173971,
#   0.1319550246050414),
#  ('Amp4',
#   8,
#   -3.45805,
#   18.5978,
#   -0.9931569916955207,
#   0.0006788255402313769,
#   0.23477239154835286),
#  ('Amp4',
#   9,
#   -3.52585,
#   20.0822,
#   -0.9967666610252864,
#   0.0002205971860090647,
#   0.16409637158288246),
#  ('Amp4',
#   10,
#   -3.4354,
#   20.696399999999997,
#   -0.9989388475750295,
#   4.148884777055433e-05,
#   0.09144635950472092),
#  ('Amp4',
#   11,
#   -3.5229500000000002,
#   21.1342,
#   -0.997617954060944,
#   0.00013950951197465493,
#   0.14064130201805283),
#  ('Amp5',
#   1,
#   -3.3869000000000002,
#   18.642,
#   -0.9999444253542447,
#   4.973307260996524e-07,
#   0.02061641740621164),
#  ('Amp5',
#   5,
#   -3.4574666666666665,
#   18.419422222222224,
#   -0.9990066624702224,
#   1.0161469267451176e-10,
#   0.05829027980356226),
#  ('Amp5',
#   7,
#   -3.349166666666667,
#   18.901066666666665,
#   -0.9996545145849337,
#   7.708252399844451e-06,
#   0.05084152210909875),
#  ('Amp5',
#   8,
#   -3.24765,
#   19.2379,
#   -0.999414820138052,
#   1.699142453197495e-05,
#   0.06417397577419494),
#  ('Amp5',
#   9,
#   -3.5593500000000007,
#   20.2759,
#   -0.9966856509949539,
#   0.00022893657779857548,
#   0.16772810090540338),
#  ('Amp5',
#   10,
#   -3.46825,
#   20.8535,
#   -0.9987180852317763,
#   5.508572336353679e-05,
#   0.10148741711825107),
#  ('Amp5',
#   11,
#   -3.5152,
#   21.424300000000002,
#   -0.9979593145184742,
#   0.00011062798091554517,
#   0.12985477786101313),
#  ('Amp7',
#   1,
#   -3.3944000000000005,
#   18.7363,
#   -0.9997146947988272,
#   5.784686189134448e-06,
#   0.046823640752633726),
#  ('Amp7',
#   4,
#   -3.4204803921568625,
#   18.39250588235294,
#   -0.9997967027511707,
#   3.4795082099465342e-06,
#   0.03982662019010798),
#  ('Amp7',
#   5,
#   -3.342650000000001,
#   18.39523888888889,
#   -0.9993559989685818,
#   2.230324565517894e-11,
#   0.045363860665700584),
#  ('Amp7',
#   7,
#   -3.3866666666666667,
#   18.821933333333334,
#   -0.9994856300637184,
#   1.400276215454998e-05,
#   0.06273822155946142),
#  ('Amp7',
#   8,
#   -3.266550000000001,
#   19.297599999999996,
#   -0.9996932385246048,
#   6.4493374245728395e-06,
#   0.04672443151070839),
#  ('Amp7',
#   9,
#   -3.45115,
#   19.0309,
#   -0.9988793166947805,
#   4.502826273100797e-05,
#   0.09441150618436787),
#  ('Amp7',
#   10,
#   -3.4796499999999995,
#   20.882699999999996,
#   -0.9988782885082855,
#   4.509023769483296e-05,
#   0.09523489819039196),
#  ('Amp7',
#   11,
#   -3.292827586206897,
#   20.015741379310345,
#   -0.9829435627620712,
#   0.0026671785190552936,
#   0.3556961122736146),
#  ('Amp8',
#   2,
#   -3.4698499999999997,
#   20.50515,
#   -0.9998912744553377,
#   1.3608935708123016e-06,
#   0.029543795174848824),
#  ('Amp9',
#   2,
#   -3.43515,
#   18.925449999999998,
#   -0.9999107084921589,
#   1.0128456699277827e-06,
#   0.026505392533120873),
#  ('Amp10',
#   2,
#   -3.4104500000000004,
#   18.98435,
#   -0.9999049170398376,
#   1.1129655048695854e-06,
#   0.02715491054423843),
#  ('Amp10',
#   5,
#   -3.443866666666666,
#   18.95891111111111,
#   -0.9989670009050678,
#   1.1653344753760995e-10,
#   0.05921053013026515),
#  ('Amp10',
#   7,
#   -3.3340666666666667,
#   19.0792,
#   -0.9995391952240218,
#   1.1873514689354827e-05,
#   0.058457100446328486),
#  ('Amp10',
#   8,
#   -3.2220500000000003,
#   19.6716,
#   -0.999562819988769,
#   1.0972253199488358e-05,
#   0.05502489588055747),
#  ('Amp10',
#   9,
#   -3.4111,
#   19.552699999999998,
#   -0.9988380268793627,
#   4.753924388338694e-05,
#   0.09502231316906506),
#  ('Amp10',
#   10,
#   -3.4471999999999996,
#   21.2665,
#   -0.9987345556376485,
#   5.402763870148474e-05,
#   0.10022010776286876),
#  ('Amp10',
#   11,
#   -3.181011627906977,
#   19.921593023255813,
#   -0.9879386473484756,
#   0.0015872326652408325,
#   0.28785524724379036)]

# %%
# putting them all into a dataframe
reg_stats = pd.DataFrame(reg_stat,
                        columns=['amp','run_num','slope', 'intercept', 'r_value', 'p_value', 'std_err'])

# %%
# creating another column in the dataframe with the PCR efficiency results
reg_stats['PCR Efficiency'] = np.round(((10**(-1/reg_stats['slope'])-1)*100),decimals=2)

# %%
# then aggregating the values to find the mean PCR efficiency accross all the runs for each amp.
reg_stats.groupby(by='amp').agg({'PCR Efficiency':'mean'})
# Out:
#        PCR Efficiency
# amp
# Amp1       100.048000
# Amp10       99.014286
# Amp2        95.893750
# Amp3       101.120000
# Amp4        95.983750
# Amp5        95.971429
# Amp7        97.737500
# Amp8        94.180000
# Amp9        95.480000

# %%
reg_stat = []
reg_stats = []

# %%
reg_stat = {}
for amp in dict_amp:
    print(amp)
    for qty in dict_amp[amp]:
        #print(dict_amp[amp].index.get_level_values(1))
        slope, intercept, r_value, p_value, std_err = stats.linregress(
            x = dict_amp[amp].index.get_level_values(1),
            y = dict_amp[amp]['CT']['mean']
        )
        reg_stat[str(amp)] = (slope, intercept, r_value, p_value, std_err)
# Out:
# Amp1
# Amp2
# Amp3
# Amp4
# Amp5
# Amp7
# Amp8
# Amp9
# Amp10
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_stats_mstats_common.py:160: RuntimeWarning: invalid value encountered in double_scalars
#   slope = ssxym / ssxm
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_stats_mstats_common.py:176: RuntimeWarning: divide by zero encountered in double_scalars
#   slope_stderr = np.sqrt((1 - r**2) * ssym / ssxm / df)

# %%
reg_stat
# Out:
# {'Amp1': (0.5016799455888066,
#   25.75211899209742,
#   0.15705523281596104,
#   0.44354791596860355,
#   0.6439398673099401),
#  'Amp2': (0.15986581386726006,
#   19.821717741935483,
#   0.07119674816581939,
#   0.6460520467085669,
#   0.3455948690864698),
#  'Amp3': (nan, nan, 0.0, 1.0, inf),
#  'Amp4': (0.032741042614811776,
#   20.507707902358295,
#   0.01413747918275906,
#   0.9231930703594569,
#   0.33777553652334763),
#  'Amp5': (0.40714354122868474,
#   17.042727166549874,
#   0.19527919647624484,
#   0.2335154427492217,
#   0.3361615233008019),
#  'Amp7': (0.32397532793748246,
#   18.550892687691878,
#   0.13685441127309994,
#   0.37570707548510396,
#   0.36184530797350983),
#  'Amp8': (nan, nan, 0.0, 1.0, inf),
#  'Amp9': (nan, nan, 0.0, 1.0, inf),
#  'Amp10': (0.37360947847682124,
#   17.484226821192053,
#   0.1624635869646492,
#   0.3230743456305103,
#   0.3730375188785354)}

# %%
reg_stats = pd.DataFrame.from_dict(reg_stat, orient='index',columns=('slope', 'intercept', 'r_value', 'p_value', 'std_err'))

# %%
reg_stats
# Out:
#           slope  intercept   r_value   p_value   std_err
# Amp1   0.501680  25.752119  0.157055  0.443548  0.643940
# Amp2   0.159866  19.821718  0.071197  0.646052  0.345595
# Amp3        NaN        NaN  0.000000  1.000000       inf
# Amp4   0.032741  20.507708  0.014137  0.923193  0.337776
# Amp5   0.407144  17.042727  0.195279  0.233515  0.336162
# Amp7   0.323975  18.550893  0.136854  0.375707  0.361845
# Amp8        NaN        NaN  0.000000  1.000000       inf
# Amp9        NaN        NaN  0.000000  1.000000       inf
# Amp10  0.373609  17.484227  0.162464  0.323074  0.373038

# %%
dict_amp['Amp3']
# Out:
#                        CT
#                      mean       std count
# Amp Run Quantity
# 3   1   -1.0      23.1570  0.033941     2
#          0.0      17.7395  2.288905     2
#          1.0      16.1415  0.012021     2
#          2.0      12.6250  0.009899     2
#          3.0       9.2375  0.031820     2
